# %% [markdown]
# ### Backpropagation
#
# - Forward Pass 시 Local Gradient를 미리 계산하여 저장해둔다
# - Backward Pass 시 Local Gradient와 Global Gradient를 곱하여 최종 미분 값을 얻는다
# - [설명 영상](https://www.youtube.com/watch?v=1Q_etC_GHHk)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 그레이디언트 소실과 폭주 문제
